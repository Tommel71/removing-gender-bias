# %% [markdown]
# # Training a low gender-bias model from unfair data

# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Parameters

# %%
# main variable to change, use the method of using the gender variable to make the model ignore the predictors for the gender
# bake_in_bias = False
bake_in_bias = True
cutoff = 2
# set numpy seed
np.random.seed(1)

# %% [markdown]
# Convention for naming classes: female: 0, male: 1, can also be read as: unbiased: 0 or biased: 1
# I call the variable often latent variable, but its actually an attribute in the data, so it is not latent
# But if we can make the model ignore this fake latent variable, it should also be able to ignore a real latent variable
# Be careful with the gender variables: There are 3 different ones. The latent gender variable,
# the gender variable in the data which we can change to control the outcome and the actual gender
# The latent gender variable is always the same as the actual gender variable here.

# %% [markdown]
# ### Functions

# %%
def analyse_classification(y_pred, x_val, y_val, gender_val):
    df = pd.DataFrame(x_val)
    df.columns = ["score1", "score2", "latent_variable", "gender_variable"]
    df = pd.concat([df, pd.DataFrame({"prediction": y_pred > 0, "actual": list(map(bool, y_val)), "gender": gender_val})],axis=1)
    df["TP"] = df["prediction"] & df["actual"]
    df["TN"] = ~df["prediction"] & ~df["actual"]
    df["FP"] = df["prediction"] & ~df["actual"]
    df["FN"] = ~df["prediction"] & df["actual"]
    agg = df.groupby("gender").sum()
    agg.index = ["female", "male"]
    print(agg)
    winners = df[y_pred> 0]
    print(winners)
    means = winners.groupby("gender").mean().iloc[:,:2].sum(axis= 1)

    return means[0], means[1]

# now for validating this approach we create the same data but this time balanced
def eval(x_val, y_val, gender_val):
    y_pred = net(x_val).detach().numpy()
    print("accuracy: ", ((y_pred > 0) == y_val.detach().numpy()).sum().item() / len(y_val))
    return analyse_classification(y_pred, x_val, y_val, gender_val)

def create_data(n_data=100000, unfairness=0, only_male=False, only_female=False):
    print("Generate data...")
    # generate random data
    x = np.random.randn(n_data, 2)
    # sample 90% male and 10% female
    gender = np.random.choice([0, 1], size=n_data, p=[0.5, 0.5]).astype(float)
    gender_for_model = gender

    if only_male:
        gender_for_model = np.ones(n_data)

    if only_female:
        gender_for_model = np.zeros(n_data)

    assert not (only_male and only_female)
    # convert gender to float

    # concatenate gender to the data
    # think of x without the gender as scores in a test and then add unfairness with the gender variable.
    y = np.array([1 if sum(x[i,:]) > cutoff - gender[i]* unfairness else 0 for i in range(len(x))])

    latent_gender = gender
    # concatenate latent information, we cant manipulate this, this is in the data
    # this is even stronger than just a latent variable that is learned, this does not have to be learned
    # it is provided as an attribute, so even easier for the model to exploit
    # The goal is to make the model ignore this. If we can do that we can also do it with a latent variable
    x = np.concatenate((x, latent_gender.reshape(-1, 1)), axis=1)


    x = np.concatenate((x, gender_for_model.reshape(-1, 1)), axis=1) # concatenate gender information that we can manipulate

    # undersample the majority class
    mask_accepted = y == 1
    mask_male = gender == 1



    mask_accepted_and_male = mask_accepted & mask_male
    mask_accepted_and_female = mask_accepted & ~mask_male
    mask_not_accepted_and_male = ~mask_accepted & mask_male
    mask_not_accepted_and_female = ~mask_accepted & ~mask_male
    minimal_data = 1000 # very ugly and hacky

    def get_balanced_data(data):
        return np.concatenate([data[mask_accepted_and_male][:minimal_data],
                               data[mask_accepted_and_female][:minimal_data],
                               data[mask_not_accepted_and_male][:minimal_data],
                               data[mask_not_accepted_and_female][:minimal_data]])
    # balance data
    x = get_balanced_data(x)
    y = get_balanced_data(y)
    gender = get_balanced_data(gender)


    # get a permutation of the data
    perm = np.random.permutation(4*minimal_data)
    x = x[perm]
    y = y[perm]
    gender = gender[perm]

    print(y.sum() / (4*minimal_data) * 100, "% class 2 samples")

    # convert x and y to tensors
    x = torch.from_numpy(x).float()
    y = torch.from_numpy(y).float()
    return x, y, gender

# %% [markdown]
# ### Define experiment setting

# %%
k_reps = 10

# %% [markdown]
# ### Run experiment

# %%
differences_meanscore_bake = []
differences_meanscore_nobake =[]
accuracies_bake = []
accuracies_nobake = []

for i in range(k_reps):
    for bake_in_bias in [True, False]:

        ### Create unfair training data and split train test

        x,y, gender = create_data(unfairness=1)
        n = len(x)
        # split train test data
        x_train = x[:int(n*0.8)]
        y_train = y[:int(n*0.8)]
        x_test = x[int(n*0.8):]
        y_test = y[int(n*0.8):]
        gender_train = gender[:int(n*0.8)]
        gender_test = gender[int(n*0.8):]

        ### create a neural network where that drops the gender variable if trained with bake_in_bias = False
        ### and does not drop it if trained with bake_in_bias = True
        ### Furthermore, initially the weights on the non-gender data are frozen, however I believe the model will learn on non-gender data anyway
        ### in deeper layers

        n_attributes = x.shape[1]
        # create a neural network
        class Net(nn.Module):
            def __init__(self, erased_last_var=False):
                super(Net, self).__init__()
                self.erased_last_var = erased_last_var
                self.fc1 = nn.Linear(n_attributes  - int(erased_last_var) , 5)
                self.fc2 = nn.Linear(5, 3)
                self.fc3 = nn.Linear(3, 1)


            def forward(self, x):
                # cut off last variable
                x_last = x[:, -1]
                x_rest = x[:, :-1]

                if not self.erased_last_var:
                    # right before the last layer we add the last variable, to make it have a strong effect on the output
                    x = x
                else:
                    x = x_rest

                x = self.fc1(x)
                x = self.fc2(x)
                x = self.fc3(x)

                # remove last dimension
                x = x.reshape(-1)
                return x

        net = Net(erased_last_var=(not bake_in_bias)) # if we are not baking in the bias we are not using that last variable

        # create optimizer use adam
        optimizer = optim.Adam(net.parameters(), lr=0.001)

        # training the network but freezing all the weights in the first layer except for the gender variable
        for epoch in range(3000):

            optimizer.zero_grad()
            out = net(x_train)
            loss = F.binary_cross_entropy_with_logits(out, y_train)
            loss.backward()
            if bake_in_bias:
                # set gradients to zero in the hope that there is more signal for the last variable:
                for n, w in net.named_parameters():
                    if n == "fc1.weight":
                        w.grad[:,:-1] = 0
                    if n == "fc1.bias":
                        w.grad[:-1] = 0

            optimizer.step()

        # train again, without freezing
        for epoch in range(3000):

            optimizer.zero_grad()
            out = net(x_train)
            loss = F.binary_cross_entropy_with_logits(out, y_train)
            loss.backward()

            optimizer.step()



        print(50*"*")
        print("Performance on test set (unfair), not so interesting, just to check if the model works well on similar data it was trained on")
        eval(x_test, y_test, gender_test)

        # the only_female gender labels do not have any effect on the model without baking because that one
        # drops the last variable as defined above
        x_val_fair, y_val_fair, gender_val_fair = create_data(unfairness=0, only_female=True)
        print(50*"*")
        print("Now on fair evaluation data with all genders set to female on the gender variable (latent variable still contains real gender information):")
        means = eval(x_val_fair, y_val_fair, gender_val_fair)
        print("Mean score of person getting accepted, should be very similar for both classes otherwise there is bias because one class gets in with a lower score on average")
        print(f"Mean score of female getting accepted: {means[0]}, \nMean score of male   getting accepted: {means[1]}")
        print("If the model used the latent variable, it would not perform well on fair data and the means would differ (more)")

        x_val_fair, y_val_fair, gender_val_fair = create_data(unfairness=0, only_female=True)
        eval(x_val_fair, y_val_fair, gender_val_fair)
        x_val_fair_male = x_val_fair.clone()
        x_val_fair_male[:, -1] = 1
        eval(x_val_fair_male, y_val_fair, gender_val_fair)
        x_val_fair_female = x_val_fair.clone()

        # Add logits of the all female and all male prediction settings to get a combined prediction that should balance the perks of males and females
        y_pred_female = net(x_val_fair_female).detach().numpy()
        y_pred_male = net(x_val_fair_male).detach().numpy()
        merged_pred = y_pred_female + y_pred_male
        means = analyse_classification(merged_pred, x_val_fair, y_val_fair, gender_val_fair)

        # Collect data for visualization
        if bake_in_bias:
            differences_meanscore_bake.append(means[0] - means[1])
            accuracies_bake.append(((merged_pred > 0) == y_val_fair.numpy()).mean())
        else:
            differences_meanscore_nobake.append(means[0] - means[1])
            accuracies_nobake.append(((merged_pred > 0) == y_val_fair.numpy()).mean())
# Out:
# Generate data...
# 50.0 % class 2 samples
# **************************************************
# Performance on test set (unfair), not so interesting, just to check if the model works well on similar data it was trained on
# accuracy:  0.9975
#         prediction  actual   TP   TN  FP  FN
# female         216     214  214  196   2   0
# male           195     195  195  193   0   0
#              score1           score2 latent_variable gender_variable  \
# 0    tensor(0.8776)   tensor(1.9706)      tensor(0.)      tensor(0.)
# 2    tensor(0.1509)   tensor(1.5719)      tensor(1.)      tensor(1.)
# 3    tensor(1.9221)   tensor(1.2600)      tensor(0.)      tensor(0.)
# 4    tensor(1.1392)   tensor(1.0429)      tensor(0.)      tensor(0.)
# 5    tensor(0.4730)   tensor(1.6185)      tensor(0.)      tensor(0.)
# ..              ...              ...             ...             ...
# 791  tensor(0.5881)   tensor(0.6054)      tensor(1.)      tensor(1.)
# 792  tensor(1.5975)   tensor(1.3477)      tensor(0.)      tensor(0.)
# 793  tensor(2.5283)  tensor(-0.2486)      tensor(0.)      tensor(0.)
# 795  tensor(1.5414)  tensor(-0.2440)      tensor(1.)      tensor(1.)
# 796  tensor(2.0397)   tensor(1.5968)      tensor(0.)      tensor(0.)
#
#      prediction  actual  gender    TP     TN     FP     FN
# 0          True    True     0.0  True  False  False  False
# 2          True    True     1.0  True  False  False  False
# 3          True    True     0.0  True  False  False  False
# 4          True    True     0.0  True  False  False  False
# 5          True    True     0.0  True  False  False  False
# ..          ...     ...     ...   ...    ...    ...    ...
# 791        True    True     1.0  True  False  False  False
# 792        True    True     0.0  True  False  False  False
# 793        True    True     0.0  True  False  False  False
# 795        True    True     1.0  True  False  False  False
# 796        True    True     0.0  True  False  False  False
#
# [411 rows x 11 columns]
# Generate data...
# 50.0 % class 2 samples
# **************************************************
# Now on fair evaluation data with all genders set to female on the gender variable (latent variable still contains real gender information):
# accuracy:  0.9865
#         prediction  actual    TP   TN  FP  FN
# female        1001    1000  1000  999   1   0
# male          1053    1000  1000  947  53   0
#                score1          score2 latent_variable gender_variable  \
# 0      tensor(0.5907)  tensor(1.8124)      tensor(1.)      tensor(0.)
# 1     tensor(-0.4520)  tensor(2.9106)      tensor(1.)      tensor(0.)
# 2      tensor(3.0068)  tensor(0.3229)      tensor(0.)      tensor(0.)
# 6      tensor(1.0328)  tensor(0.6481)      tensor(1.)      tensor(0.)
# 7      tensor(0.9325)  tensor(1.2247)      tensor(0.)      tensor(0.)
# ...               ...             ...             ...             ...
# 3986  tensor(-0.0462)  tensor(2.0856)      tensor(1.)      tensor(0.)
# 3987   tensor(1.1492)  tensor(0.9567)      tensor(1.)      tensor(0.)
# 3990   tensor(1.4940)  tensor(1.5133)      tensor(0.)      tensor(0.)
# 3991   tensor(1.1598)  tensor(0.8455)      tensor(1.)      tensor(0.)
# 3997   tensor(1.0786)  tensor(1.8093)      tensor(0.)      tensor(0.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 0           True    True     1.0   True  False  False  False
# 1           True    True     1.0   True  False  False  False
# 2           True    True     0.0   True  False  False  False
# 6           True   False     1.0  False  False   True  False
# 7           True    True     0.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3986        True    True     1.0   True  False  False  False
# 3987        True    True     1.0   True  False  False  False
# 3990        True    True     0.0   True  False  False  False
# 3991        True    True     1.0   True  False  False  False
# 3997        True    True     0.0   True  False  False  False
#
# [2054 rows x 11 columns]
# Mean score of person getting accepted, should be very similar for both classes otherwise there is bias because one class gets in with a lower score on average
# Mean score of female getting accepted: 1.999000999000999,
# Mean score of male   getting accepted: 1.949667616334283
# If the model used the latent variable, it would not perform well on fair data and the means would differ (more)
# Generate data...
# 50.0 % class 2 samples
# accuracy:  0.98525
#         prediction  actual    TP    TN  FP  FN
# female        1000    1000  1000  1000   0   0
# male          1059    1000  1000   941  59   0
#               score1          score2 latent_variable gender_variable  \
# 1     tensor(0.8851)  tensor(1.2609)      tensor(1.)      tensor(0.)
# 2     tensor(1.1013)  tensor(1.7544)      tensor(1.)      tensor(0.)
# 4     tensor(0.9704)  tensor(1.1010)      tensor(1.)      tensor(0.)
# 5     tensor(1.1733)  tensor(1.1257)      tensor(0.)      tensor(0.)
# 6     tensor(1.4452)  tensor(1.6193)      tensor(1.)      tensor(0.)
# ...              ...             ...             ...             ...
# 3992  tensor(1.0434)  tensor(1.3818)      tensor(1.)      tensor(0.)
# 3994  tensor(2.1344)  tensor(0.2103)      tensor(0.)      tensor(0.)
# 3995  tensor(1.7618)  tensor(0.2590)      tensor(0.)      tensor(0.)
# 3996  tensor(1.9990)  tensor(0.0856)      tensor(0.)      tensor(0.)
# 3998  tensor(0.6547)  tensor(1.3799)      tensor(0.)      tensor(0.)
#
#       prediction  actual  gender    TP     TN     FP     FN
# 1           True    True     1.0  True  False  False  False
# 2           True    True     1.0  True  False  False  False
# 4           True    True     1.0  True  False  False  False
# 5           True    True     0.0  True  False  False  False
# 6           True    True     1.0  True  False  False  False
# ...          ...     ...     ...   ...    ...    ...    ...
# 3992        True    True     1.0  True  False  False  False
# 3994        True    True     0.0  True  False  False  False
# 3995        True    True     0.0  True  False  False  False
# 3996        True    True     0.0  True  False  False  False
# 3998        True    True     0.0  True  False  False  False
#
# [2059 rows x 11 columns]
# accuracy:  0.9325
#         prediction  actual    TP   TN   FP  FN
# female        1091    1000  1000  909   91   0
# male          1179    1000  1000  821  179   0
#               score1          score2 latent_variable gender_variable  \
# 1     tensor(0.8851)  tensor(1.2609)      tensor(1.)      tensor(1.)
# 2     tensor(1.1013)  tensor(1.7544)      tensor(1.)      tensor(1.)
# 4     tensor(0.9704)  tensor(1.1010)      tensor(1.)      tensor(1.)
# 5     tensor(1.1733)  tensor(1.1257)      tensor(0.)      tensor(1.)
# 6     tensor(1.4452)  tensor(1.6193)      tensor(1.)      tensor(1.)
# ...              ...             ...             ...             ...
# 3993  tensor(0.9617)  tensor(0.4447)      tensor(1.)      tensor(1.)
# 3994  tensor(2.1344)  tensor(0.2103)      tensor(0.)      tensor(1.)
# 3995  tensor(1.7618)  tensor(0.2590)      tensor(0.)      tensor(1.)
# 3996  tensor(1.9990)  tensor(0.0856)      tensor(0.)      tensor(1.)
# 3998  tensor(0.6547)  tensor(1.3799)      tensor(0.)      tensor(1.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 1           True    True     1.0   True  False  False  False
# 2           True    True     1.0   True  False  False  False
# 4           True    True     1.0   True  False  False  False
# 5           True    True     0.0   True  False  False  False
# 6           True    True     1.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3993        True   False     1.0  False  False   True  False
# 3994        True    True     0.0   True  False  False  False
# 3995        True    True     0.0   True  False  False  False
# 3996        True    True     0.0   True  False  False  False
# 3998        True    True     0.0   True  False  False  False
#
# [2270 rows x 11 columns]
#         prediction  actual    TP   TN   FP  FN
# female        1032    1000  1000  968   32   0
# male          1122    1000  1000  878  122   0
#               score1          score2 latent_variable gender_variable  \
# 1     tensor(0.8851)  tensor(1.2609)      tensor(1.)      tensor(0.)
# 2     tensor(1.1013)  tensor(1.7544)      tensor(1.)      tensor(0.)
# 4     tensor(0.9704)  tensor(1.1010)      tensor(1.)      tensor(0.)
# 5     tensor(1.1733)  tensor(1.1257)      tensor(0.)      tensor(0.)
# 6     tensor(1.4452)  tensor(1.6193)      tensor(1.)      tensor(0.)
# ...              ...             ...             ...             ...
# 3993  tensor(0.9617)  tensor(0.4447)      tensor(1.)      tensor(0.)
# 3994  tensor(2.1344)  tensor(0.2103)      tensor(0.)      tensor(0.)
# 3995  tensor(1.7618)  tensor(0.2590)      tensor(0.)      tensor(0.)
# 3996  tensor(1.9990)  tensor(0.0856)      tensor(0.)      tensor(0.)
# 3998  tensor(0.6547)  tensor(1.3799)      tensor(0.)      tensor(0.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 1           True    True     1.0   True  False  False  False
# 2           True    True     1.0   True  False  False  False
# 4           True    True     1.0   True  False  False  False
# 5           True    True     0.0   True  False  False  False
# 6           True    True     1.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3993        True   False     1.0  False  False   True  False
# 3994        True    True     0.0   True  False  False  False
# 3995        True    True     0.0   True  False  False  False
# 3996        True    True     0.0   True  False  False  False
# 3998        True    True     0.0   True  False  False  False
#
# [2154 rows x 11 columns]
# Generate data...
# 50.0 % class 2 samples
# **************************************************
# Performance on test set (unfair), not so interesting, just to check if the model works well on similar data it was trained on
# accuracy:  1.0
#         prediction  actual   TP   TN  FP  FN
# female         201     201  201  203   0   0
# male           188     188  188  208   0   0
#               score1           score2 latent_variable gender_variable  \
# 4     tensor(1.0920)   tensor(1.5078)      tensor(1.)      tensor(1.)
# 5     tensor(0.3485)   tensor(1.0193)      tensor(1.)      tensor(1.)
# 8     tensor(0.7134)   tensor(1.2896)      tensor(0.)      tensor(0.)
# 10   tensor(-0.1970)   tensor(2.0078)      tensor(1.)      tensor(1.)
# 11    tensor(2.0354)   tensor(0.8328)      tensor(0.)      tensor(0.)
# ..               ...              ...             ...             ...
# 789   tensor(1.5969)   tensor(0.6303)      tensor(0.)      tensor(0.)
# 792   tensor(0.8392)   tensor(1.1600)      tensor(1.)      tensor(1.)
# 793   tensor(1.5857)  tensor(-0.1507)      tensor(1.)      tensor(1.)
# 797   tensor(1.1045)   tensor(2.3606)      tensor(0.)      tensor(0.)
# 798   tensor(0.1487)   tensor(2.5887)      tensor(1.)      tensor(1.)
#
#      prediction  actual  gender    TP     TN     FP     FN
# 4          True    True     1.0  True  False  False  False
# 5          True    True     1.0  True  False  False  False
# 8          True    True     0.0  True  False  False  False
# 10         True    True     1.0  True  False  False  False
# 11         True    True     0.0  True  False  False  False
# ..          ...     ...     ...   ...    ...    ...    ...
# 789        True    True     0.0  True  False  False  False
# 792        True    True     1.0  True  False  False  False
# 793        True    True     1.0  True  False  False  False
# 797        True    True     0.0  True  False  False  False
# 798        True    True     1.0  True  False  False  False
#
# [389 rows x 11 columns]
# Generate data...
# 50.0 % class 2 samples
# **************************************************
# Now on fair evaluation data with all genders set to female on the gender variable (latent variable still contains real gender information):
# accuracy:  0.95675
#         prediction  actual    TP   TN   FP  FN
# female        1001    1000  1000  999    1   0
# male          1172    1000  1000  828  172   0
#                score1           score2 latent_variable gender_variable  \
# 5     tensor(-0.7021)   tensor(2.7967)      tensor(1.)      tensor(0.)
# 6      tensor(0.8373)   tensor(1.1707)      tensor(0.)      tensor(0.)
# 7      tensor(2.2060)  tensor(-0.1774)      tensor(1.)      tensor(0.)
# 9      tensor(1.2124)   tensor(1.1441)      tensor(1.)      tensor(0.)
# 11     tensor(0.6538)   tensor(0.9565)      tensor(1.)      tensor(0.)
# ...               ...              ...             ...             ...
# 3994   tensor(0.7696)   tensor(0.7025)      tensor(1.)      tensor(0.)
# 3995   tensor(1.1904)   tensor(1.1643)      tensor(0.)      tensor(0.)
# 3996   tensor(0.2005)   tensor(2.6513)      tensor(0.)      tensor(0.)
# 3997   tensor(2.0317)   tensor(1.0035)      tensor(1.)      tensor(0.)
# 3999   tensor(0.6873)   tensor(1.3257)      tensor(0.)      tensor(0.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 5           True    True     1.0   True  False  False  False
# 6           True    True     0.0   True  False  False  False
# 7           True    True     1.0   True  False  False  False
# 9           True    True     1.0   True  False  False  False
# 11          True   False     1.0  False  False   True  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3994        True   False     1.0  False  False   True  False
# 3995        True    True     0.0   True  False  False  False
# 3996        True    True     0.0   True  False  False  False
# 3997        True    True     1.0   True  False  False  False
# 3999        True    True     0.0   True  False  False  False
#
# [2173 rows x 11 columns]
# Mean score of person getting accepted, should be very similar for both classes otherwise there is bias because one class gets in with a lower score on average
# Mean score of female getting accepted: 1.999000999000999,
# Mean score of male   getting accepted: 1.8532423208191127
# If the model used the latent variable, it would not perform well on fair data and the means would differ (more)
# Generate data...
# 50.0 % class 2 samples
# accuracy:  0.956
#         prediction  actual    TP   TN   FP  FN
# female        1002    1000  1000  998    2   0
# male          1174    1000  1000  826  174   0
#               score1          score2 latent_variable gender_variable  \
# 0     tensor(1.1189)  tensor(1.3076)      tensor(0.)      tensor(0.)
# 2     tensor(1.1080)  tensor(1.0803)      tensor(1.)      tensor(0.)
# 5     tensor(0.8861)  tensor(1.4564)      tensor(0.)      tensor(0.)
# 9     tensor(1.3579)  tensor(0.9158)      tensor(1.)      tensor(0.)
# 10    tensor(2.3189)  tensor(0.3815)      tensor(1.)      tensor(0.)
# ...              ...             ...             ...             ...
# 3992  tensor(1.0605)  tensor(2.6342)      tensor(1.)      tensor(0.)
# 3994  tensor(0.9278)  tensor(2.5247)      tensor(1.)      tensor(0.)
# 3995  tensor(0.5403)  tensor(2.3515)      tensor(1.)      tensor(0.)
# 3997  tensor(0.3974)  tensor(2.3875)      tensor(1.)      tensor(0.)
# 3999  tensor(0.6194)  tensor(1.0345)      tensor(1.)      tensor(0.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 0           True    True     0.0   True  False  False  False
# 2           True    True     1.0   True  False  False  False
# 5           True    True     0.0   True  False  False  False
# 9           True    True     1.0   True  False  False  False
# 10          True    True     1.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3992        True    True     1.0   True  False  False  False
# 3994        True    True     1.0   True  False  False  False
# 3995        True    True     1.0   True  False  False  False
# 3997        True    True     1.0   True  False  False  False
# 3999        True   False     1.0  False  False   True  False
#
# [2176 rows x 11 columns]
# accuracy:  0.956
#         prediction  actual    TP   TN   FP  FN
# female        1002    1000  1000  998    2   0
# male          1174    1000  1000  826  174   0
#               score1          score2 latent_variable gender_variable  \
# 0     tensor(1.1189)  tensor(1.3076)      tensor(0.)      tensor(1.)
# 2     tensor(1.1080)  tensor(1.0803)      tensor(1.)      tensor(1.)
# 5     tensor(0.8861)  tensor(1.4564)      tensor(0.)      tensor(1.)
# 9     tensor(1.3579)  tensor(0.9158)      tensor(1.)      tensor(1.)
# 10    tensor(2.3189)  tensor(0.3815)      tensor(1.)      tensor(1.)
# ...              ...             ...             ...             ...
# 3992  tensor(1.0605)  tensor(2.6342)      tensor(1.)      tensor(1.)
# 3994  tensor(0.9278)  tensor(2.5247)      tensor(1.)      tensor(1.)
# 3995  tensor(0.5403)  tensor(2.3515)      tensor(1.)      tensor(1.)
# 3997  tensor(0.3974)  tensor(2.3875)      tensor(1.)      tensor(1.)
# 3999  tensor(0.6194)  tensor(1.0345)      tensor(1.)      tensor(1.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 0           True    True     0.0   True  False  False  False
# 2           True    True     1.0   True  False  False  False
# 5           True    True     0.0   True  False  False  False
# 9           True    True     1.0   True  False  False  False
# 10          True    True     1.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3992        True    True     1.0   True  False  False  False
# 3994        True    True     1.0   True  False  False  False
# 3995        True    True     1.0   True  False  False  False
# 3997        True    True     1.0   True  False  False  False
# 3999        True   False     1.0  False  False   True  False
#
# [2176 rows x 11 columns]
#         prediction  actual    TP   TN   FP  FN
# female        1002    1000  1000  998    2   0
# male          1174    1000  1000  826  174   0
#               score1          score2 latent_variable gender_variable  \
# 0     tensor(1.1189)  tensor(1.3076)      tensor(0.)      tensor(0.)
# 2     tensor(1.1080)  tensor(1.0803)      tensor(1.)      tensor(0.)
# 5     tensor(0.8861)  tensor(1.4564)      tensor(0.)      tensor(0.)
# 9     tensor(1.3579)  tensor(0.9158)      tensor(1.)      tensor(0.)
# 10    tensor(2.3189)  tensor(0.3815)      tensor(1.)      tensor(0.)
# ...              ...             ...             ...             ...
# 3992  tensor(1.0605)  tensor(2.6342)      tensor(1.)      tensor(0.)
# 3994  tensor(0.9278)  tensor(2.5247)      tensor(1.)      tensor(0.)
# 3995  tensor(0.5403)  tensor(2.3515)      tensor(1.)      tensor(0.)
# 3997  tensor(0.3974)  tensor(2.3875)      tensor(1.)      tensor(0.)
# 3999  tensor(0.6194)  tensor(1.0345)      tensor(1.)      tensor(0.)
#
#       prediction  actual  gender     TP     TN     FP     FN
# 0           True    True     0.0   True  False  False  False
# 2           True    True     1.0   True  False  False  False
# 5           True    True     0.0   True  False  False  False
# 9           True    True     1.0   True  False  False  False
# 10          True    True     1.0   True  False  False  False
# ...          ...     ...     ...    ...    ...    ...    ...
# 3992        True    True     1.0   True  False  False  False
# 3994        True    True     1.0   True  False  False  False
# 3995        True    True     1.0   True  False  False  False
# 3997        True    True     1.0   True  False  False  False
# 3999        True   False     1.0  False  False   True  False
#
# [2176 rows x 11 columns]
# Generate data...
# 50.0 % class 2 samples

# %% [markdown]
# ### Plotting

# %%
pd.DataFrame({"bake": differences_meanscore_bake, "nobake": differences_meanscore_nobake}).plot(kind="line", title="Differences in mean score of accepted applicants")
# add zero horizontal line
plt.axhline(0, color="black")
plt.show()

pd.DataFrame({"bake": accuracies_bake, "nobake": accuracies_nobake}).plot(kind="line", title="Accuracy of model on fair data, predicting if candidate is admitted")
plt.show()

# %% [markdown]
# Almost 100% sure that it is not the baking (freezing non-gender variables and training) that helps with the bias, but just the use of the variable while training

# %% [markdown]
# TODO: Try around more with adding the gender variable on deeper layers to increase the signal. Just adding it in the final layer does not work, already tried that.
# TODO: Use different data. Use unbalanced data. Use multiple gender variables to distract the model more from the gender predictors in the data
